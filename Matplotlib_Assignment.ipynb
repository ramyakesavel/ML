# %%
#1. We have the min and max temperatures in a city In India for each months of the year.
#We would like to find a function to describe this and show it graphically, the dataset given below

import numpy as np

max_temp = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
min_temp = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

import matplotlib.pyplot as plt
months = np.arange(12)
plt.plot(months, max_temp, 'go')
plt.plot(months, min_temp, 'ko')
plt.xlabel('Month')
plt.ylabel('Min and max temperature')
# Out:
# Text(0, 0.5, 'Min and max temperature')

# %%
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 1.8 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temps, months,
                                      max_temp, [40, 20, 0])
res_min, cov_min = optimize.curve_fit(yearly_temps, months,
                                      min_temp, [-40, 20, 0])

# %%
days = np.linspace(0, 12, num=365)

plt.figure()
plt.plot(months, max_temp, 'go')
plt.plot(days, yearly_temps(days, *res_max), 'm-')
plt.plot(months, min_temp, 'ko')
plt.plot(days, yearly_temps(days, *res_min), 'y-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %%
#2.1 Matplotlib:
#This assignment is for visualization using matplotlib:data to use:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import math
url='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
df=pd.read_csv(url)
df['sex'].fillna(value='other')
df['fare'].fillna(value='0.0')
#df.head()
df['sex'].value_counts().plot.pie()

# %%
#2.2 Create a scatterplot with the Fare paid and the Age, differ the plot color by gender. differ the plot color by gender
import seaborn as sns
sns.scatterplot(x=df['age'], y=df['fare'],hue=df['sex'])
